# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Benchmark Árbol de Segmentos 2D\n",
    "Comparación de tiempos entre operaciones con Árbol de Segmentos 2D vs implementación Naïve."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "import numpy as np\n",
    "import time\n",
    "\n",
    "# Configuración\n",
    "N = 256\n",
    "grid = np.random.randint(0, 10, (N, N))\n",
    "\n",
    "def query_naive(g, x1, y1, x2, y2):\n",
    "    return g[x1:x2+1, y1:y2+1].sum()\n",
    "\n",
    "# Cargar heatmap final generado por C++\n",
    "matriz = np.loadtxt('../data/heatmap_output.txt')\n",
    "\n",
    "print(\"Matriz cargada:\", matriz.shape)"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Benchmark naive\n",
    "iters = 2000\n",
    "t0 = time.time()\n",
    "for _ in range(iters):\n",
    "    x1 = np.random.randint(0, N)\n",
    "    y1 = np.random.randint(0, N)\n",
    "    x2 = np.random.randint(x1, N)\n",
    "    y2 = np.random.randint(y1, N)\n",
    "    query_naive(grid, x1, y1, x2, y2)\n",
    "t1 = time.time()\n",
    "\n",
    "print(f\"Tiempo naive para {iters} consultas: {t1 - t0:.4f} s\")"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### Para comparar con el 2D Segment Tree\n",
    "Ejecuta en C++ un benchmark similar y guarda el tiempo total para comparar."
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python",
   "version": "3.10"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
